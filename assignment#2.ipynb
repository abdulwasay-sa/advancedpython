# %%
# Assigment : Compare 5 different countries population & plot the population

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df= pd.read_csv('countries.csv')
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
# Compare Five countries & plot their population :  Bahrain, Kuwait, Oman, Saudi Arabia, Yemen, Rep. (gulf countries)

# %%
bahrain = df[df.country == 'Bahrain']  # filter operation ===> only with Bahrain data
bahrain
# Out:
#     country  year  population
# 84  Bahrain  1952      120447
# 85  Bahrain  1957      138655
# 86  Bahrain  1962      171863
# 87  Bahrain  1967      202182
# 88  Bahrain  1972      230800
# 89  Bahrain  1977      297410
# 90  Bahrain  1982      377967
# 91  Bahrain  1987      454612
# 92  Bahrain  1992      529491
# 93  Bahrain  1997      598561
# 94  Bahrain  2002      656397
# 95  Bahrain  2007      708573

# %%
kuwait = df[df.country == 'Kuwait']  # filter operation ===> only with Kuwait data
kuwait
# Out:
#     country  year  population
# 852  Kuwait  1952      160000
# 853  Kuwait  1957      212846
# 854  Kuwait  1962      358266
# 855  Kuwait  1967      575003
# 856  Kuwait  1972      841934
# 857  Kuwait  1977     1140357
# 858  Kuwait  1982     1497494
# 859  Kuwait  1987     1891487
# 860  Kuwait  1992     1418095
# 861  Kuwait  1997     1765345
# 862  Kuwait  2002     2111561
# 863  Kuwait  2007     2505559

# %%
oman = df[df.country == 'Oman']  # filter operation ===> only with Oman data
oman
# Out:
#      country  year  population
# 1152    Oman  1952      507833
# 1153    Oman  1957      561977
# 1154    Oman  1962      628164
# 1155    Oman  1967      714775
# 1156    Oman  1972      829050
# 1157    Oman  1977     1004533
# 1158    Oman  1982     1301048
# 1159    Oman  1987     1593882
# 1160    Oman  1992     1915208
# 1161    Oman  1997     2283635
# 1162    Oman  2002     2713462
# 1163    Oman  2007     3204897

# %%
ksa = df[df.country == 'Saudi Arabia']  # filter operation ===> only with Saudi Arabia data
ksa
# Out:
#            country  year  population
# 1308  Saudi Arabia  1952     4005677
# 1309  Saudi Arabia  1957     4419650
# 1310  Saudi Arabia  1962     4943029
# 1311  Saudi Arabia  1967     5618198
# 1312  Saudi Arabia  1972     6472756
# 1313  Saudi Arabia  1977     8128505
# 1314  Saudi Arabia  1982    11254672
# 1315  Saudi Arabia  1987    14619745
# 1316  Saudi Arabia  1992    16945857
# 1317  Saudi Arabia  1997    21229759
# 1318  Saudi Arabia  2002    24501530
# 1319  Saudi Arabia  2007    27601038

# %%
yemen = df[df.country == 'Yemen, Rep.']  # filter operation ===> only with Yemen, Rep. data
yemen
# Out:
#           country  year  population
# 1668  Yemen, Rep.  1952     4963829
# 1669  Yemen, Rep.  1957     5498090
# 1670  Yemen, Rep.  1962     6120081
# 1671  Yemen, Rep.  1967     6740785
# 1672  Yemen, Rep.  1972     7407075
# 1673  Yemen, Rep.  1977     8403990
# 1674  Yemen, Rep.  1982     9657618
# 1675  Yemen, Rep.  1987    11219340
# 1676  Yemen, Rep.  1992    13367997
# 1677  Yemen, Rep.  1997    15826497
# 1678  Yemen, Rep.  2002    18701257
# 1679  Yemen, Rep.  2007    22211743

# %%
plt.plot(bahrain.year,bahrain.population)
plt.plot(kuwait.year,kuwait.population)
plt.plot(oman.year,oman.population)
plt.plot(ksa.year,ksa.population)
plt.plot(yemen.year,yemen.population)

plt.xlabel('population')
# Set the y axis label of the current axis.
plt.ylabel('year')
# Set a title of the current axes.
plt.title('Gulf Countries - population comparision')
# show a legend on the plot
plt.legend(['Bahrain', 'Kuwait', 'Oman', 'Saudi Arabia','Yemen'])
# Display a figure.
plt.show()
